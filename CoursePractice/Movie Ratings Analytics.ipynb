# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/silver/Desktop/PythonLearning/PythonAtoZ/CoursePractice'

# %%
#Read the file with direct path:

movies = pd.read_csv('/Users/silver/Desktop/PythonLearning/PythonAtoZ/PracticeDatasets/Section6_ Advanced Visualization/P4-Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
#Get the top 5 rows
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating',\
       'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
#tell us some stats 
#movies.describe()

# %%
#Change the data type
movies.Film = movies.Film.astype("category")

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info() #column Film change to "category" from object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype("category")
movies.Year = movies.Year.astype("category")

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
#If you want to know what unique value in the category
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
#Standard import sets
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Jointplots

# %%
#kind = cluster
j = sns.jointplot(data = movies, \
                  x = "CriticRating", \
                  y = "AudienceRating")

# %%
#Change the plot kind to hexagon
j = sns.jointplot(data = movies, \
                  x = "CriticRating", \
                  y = "AudienceRating",
                  kind = "hex"
                 )

# %%
#<<< Chart 1

# %% [markdown]
# ---

# %% [markdown]
# ## Histograms

# %%
#already know this method:
m1 = sns.displot(movies.AudienceRating, bins = 15)

# %%
sns.set_style('darkgrid')
m2 = sns.displot(movies.CriticRating, bins = 15)

# %%
sns.set_style('darkgrid') #darkgrid / whitegrid
n1 = plt.hist(movies.AudienceRating, bins = 15)

# %%
#<<<CHART 2

# %%
n2 = plt.hist(movies.CriticRating, bins = 15) #Uniform Distribute

# %%
#<<<CHART 3

# %% [markdown]
# ---

# %% [markdown]
# ## Stacked Histograms

# %%
#Create Filter
# movies.Genre == "Drama"  
# movies[movies.Genre == "Drama"].BudgetMillions #Square Bracket!!!!

plt.hist(movies[movies.Genre == "Action"].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == "Drama"].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == "Thriller"].BudgetMillions, bins = 15)
plt.show()

# %%
plt.hist([movies[movies.Genre == "Action"].BudgetMillions,\
          movies[movies.Genre == "Drama"].BudgetMillions,\
          movies[movies.Genre == "Thriller"].BudgetMillions,\
          movies[movies.Genre == "Comedy"].BudgetMillions
          ],\
            bins = 15, stacked =  True
        )
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = list()
mylabels = list()

for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)
h = plt.hist(list1, bins = 30, stacked = True, rwidth=1, label=mylabels)
plt.legend()
plt.show()

#     plt.hist(movies[movies.Genre == gen].BudgetMillions,
#             bins = 15, stacked =  True
#         )
# plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## KDE Plot

# %%
vis1 = sns.lmplot(data = movies, x = "CriticRating",\
                 y = "AudienceRating",\
                 fit_reg=False, hue = "Genre",\
                 height= 6, aspect=1)

# %%
#Define what's x & y stand for 
k1 = sns.kdeplot(x = movies.CriticRating, \
                 y = movies.AudienceRating,\
                shade = True, shade_lowest = False, \
                cmap = "Reds") 

#TIP: make the plot smoother
k1b = sns.kdeplot(x = movies.CriticRating, \
                 y = movies.AudienceRating,\
                cmap = "Reds")

# %% [markdown]
# ---

# %% [markdown]
# ## Working with Subplot()

# %%
#Standard import sets
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
k1 = sns.kdeplot(x = movies.BudgetMillions, y = movies.AudienceRating)

# %%
k2 = sns.kdeplot(x = movies.BudgetMillions, y = movies.CriticRating)

#Most concentrated between the 20 & 40 mark

# %%
#You can show (row, column) plots by using the below code
f, axes = plt.subplots(1, 2, figsize = (12, 6), sharex= True, sharey = True) 
# plt.subplots(# of row, # of column, figsize = (), sharex = True) sharex means all plots are sharing the same x scale
k1 = sns.kdeplot(x = movies.BudgetMillions, y = movies.AudienceRating, ax = axes[0])
k2 = sns.kdeplot(x = movies.BudgetMillions, y = movies.CriticRating, ax = axes[1])

k1.set(xlim = (-20, 160)) #Change the scale of x limit
# Out:
# [(-20.0, 160.0)]

# %% [markdown]
# ---

# %% [markdown]
# ## ViolinPlots

# %%
# w = sns.boxplot(data = movies, x = "Genre", y = "CriticRating")

w = sns.boxplot(data = movies[movies.Genre =="Drama"], x = "Year", y = "CriticRating")

# %%
# z = sns.violinplot(data = movies, x = "Genre", y = "CriticRating")
z = sns.violinplot(data = movies[movies.Genre =="Drama"], x = "Year", y = "CriticRating")

#Look at the concentrated part of the plot

# %% [markdown]
# ---

# %% [markdown]
# ## Creating a Facet Grid

# %%
# g = sns.FacetGrid(movies, row = "Genre", hue = "Genre")
g = sns.FacetGrid(movies, row = "Genre", col="Year", hue = "Genre")

# %%
g = sns.FacetGrid(movies, row = "Genre", col="Year", hue = "Genre")
g = g.map(plt.scatter, "CriticRating", "AudienceRating")

# %%
#Can populate with any type of chart. Example: histograms
g = sns.FacetGrid(movies, row = "Genre", col="Year", hue = "Genre")
g = g.map(plt.hist, "BudgetMillions")

# %%
#back to the scatterplots:
g = sns.FacetGrid(movies, row = "Genre", col="Year", hue = "Genre")
kws = dict(s = 50, linewidth = 0.5, edgecolor = "black")
g = g.map(plt.scatter, "CriticRating", "AudienceRating", **kws)

# %% [markdown]
# ---

# %% [markdown]
# ## Controlling Axes and Adding Diagonals

# %%
#Controlling Axes and Adding Diagonals:
g = sns.FacetGrid(movies, row = "Genre", col="Year", hue = "Genre")
kws = dict(s = 50, linewidth = 0.5, edgecolor = "black")
g = g.map(plt.scatter, "CriticRating", "AudienceRating", **kws)
g.set(xlim = (0, 100), ylim = (0, 100))

for ax in g.axes.flat: #g.axes is an array represents each in g, and .flat means iterate in a list way
    ax.plot((0, 100), (0, 100), c = "gray", ls = "--")
g.add_legend()

# %%
#<<<Chart 5

# %% [markdown]
# ---

# %% [markdown]
# ## Building Dashboards
# - A combincation of charts
# - use plt.subplots function
# - ax = axes[row, column]

# %%
#Standard import sets
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set_style = ("darkgrid")
f, axes = plt.subplots(2, 2, figsize = (15, 15))

#plot 1, 2
k1 = sns.kdeplot(x = movies.BudgetMillions, \
                 y = movies.AudienceRating, \
                 ax = axes[0, 0])
k2 = sns.kdeplot(x = movies.BudgetMillions, \
                 y = movies.CriticRating, \
                 ax = axes[0,1])
k1.set(xlim = (-40, 230)) #Change the scale of x limit
k2.set(xlim = (-40, 230))


#plot 3
z = sns.violinplot(data = movies[movies.Genre =="Drama"], \
                   x = "Year", y = "CriticRating",\
                  ax = axes[1, 0])

#plot 4
#Define what's x & y stand for 
k3 = sns.kdeplot(x = movies.CriticRating, \
                 y = movies.AudienceRating,\
                shade = True, shade_lowest = False, \
                cmap = "Reds", \
                ax = axes[1, 1]) 

##If you wanna include standard plot in the dashboard
##The input way only apply for standard plot

##Original:
## n2 = plt.hist(movies.CriticRating, bins = 15)
# axes[1, 1].hist(movies.CriticRating, bins = 15)

#TIP: make the plot smoother
k3b = sns.kdeplot(x = movies.CriticRating, \
                 y = movies.AudienceRating,\
                cmap = "Reds", \
                 ax = axes[1, 1]) 

plt.show()

# %% [markdown]
# - Seaborn is an upgrade version of pyplot
# -

# %% [markdown]
# ---

# %% [markdown]
# ## Styling Dashboard

# %%
#It's different to course Python A-Z, the below it's the up-to-date way
sns.set_theme(style = "white", rc ={"axes.facecolor":"black"})

f, axes = plt.subplots(2, 2, figsize = (15, 15))

#plot [0, 0]
k1 = sns.kdeplot(x = movies.BudgetMillions, \
                 y = movies.AudienceRating, \
                 shade = True, shade_lowest = True, cmap = "inferno",\
                 ax = axes[0, 0])
k1b = sns.kdeplot(x = movies.BudgetMillions, y = movies.AudienceRating, \
                cmap = "cool",ax = axes[0, 0])


#plot [0, 1]
k2 = sns.kdeplot(x = movies.BudgetMillions,y = movies.CriticRating, \
                 shade = True, shade_lowest = True, cmap = "inferno",\
                 ax = axes[0,1])
k2b = sns.kdeplot(x = movies.BudgetMillions,y = movies.CriticRating, \
                cmap = "cool",ax = axes[0, 1])


#plot [1, 0]
z = sns.violinplot(data = movies[movies.Genre =="Drama"], \
                   x = "Year", y = "CriticRating", ax = axes[1, 0],\
                  palette = "YlOrRd")

#plot [1, 1]
k4 = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRating,\
                shade = True, shade_lowest = False,cmap = "Blues_r", 
                ax = axes[1, 1]) 

#TIP: make the plot smoother
k4b = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRating,\
                  cmap = "gist_gray_r", \
                 ax = axes[1, 1]) 

k1.set(xlim = (-40, 230)) #Change the scale of x limit
k2.set(xlim = (-40, 230))
plt.show()

# %% [markdown]
# ---

# %%
#Thematic edits

# %%
list1 = list()
mylabels = list()

for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)
    
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27) #size of A4 paper


h = plt.hist(list1, bins = 30, stacked = True, rwidth=1, label=mylabels)
plt.title("Movie Budget Distribution", fontsize = 35,\
         color = "DarkBlue", fontname = "Times")
plt.xlabel("Budget", fontsize = 25, color = "Green")
plt.ylabel("Number of Movies", fontsize = 25, color = "Red")
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(frameon = True, fancybox = True, shadow = True, \
           prop = {"size": 13})
plt.show()
