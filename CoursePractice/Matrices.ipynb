# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np

np.reshape(*,*,'C');
# Out:
#   Cell In[2], line 3
#     np.reshape(*,*,'C');
#                 ^
# SyntaxError: invalid syntax
